# %% [markdown]
# # Pommerman Demo.
#
# This notebook demonstrates how to train Pommerman agents. Please let us know at support@pommerman.com if you run into any issues.

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#!pip install jsonmerge

#CONTENT_STORAGE_DIR = "/content/drive/My Drive/Bachelorarbeit"
#sys.path.append(CONTENT_STORAGE_DIR)
# Out:
# Collecting jsonmerge
#   Downloading https://files.pythonhosted.org/packages/3f/85/c73f8fd74a2d920935cacfb3aaf99089a22f7291f7906150e63de086a5c2/jsonmerge-1.7.0.tar.gz
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from jsonmerge) (2.6.0)
# Building wheels for collected packages: jsonmerge
#   Building wheel for jsonmerge (setup.py) ... done
#   Created wheel for jsonmerge: filename=jsonmerge-1.7.0-cp36-none-any.whl size=16739 sha256=0968f308f5e3ead9374ed3d4266185070ee6c705bf51de5e14a2df30c00c4548
#   Stored in directory: /root/.cache/pip/wheels/55/1b/1a/29f8d1d20b748b3825a0bd52c6a0defdf44aa0d150b5e6df3a
# Successfully built jsonmerge
# Installing collected packages: jsonmerge
# Successfully installed jsonmerge-1.7.0

# %%
import atexit
from datetime import datetime
import os
import random
import sys
import copy
import time
import csv

import argparse
import numpy as np

from pommerman import helpers
from pommerman import make
from pommerman import utility
from pommerman import constants

from pommerman.agents import SimpleAgent
from pommerman.agents import UcbMCTSAgent
from pommerman.agents import UcbLimitMCTSAgent
from pommerman.agents import UcbMRMCTSAgent
from pommerman.agents import UcbMRLimitMCTSAgent
from pommerman.agents.abstract_mcts_skeleton import AbstractMCTSSkeleton

# %%
def run_tournament(tournament_name, agent_pool1, agent_pool2, match_count, AllVsAll=True, seed=None):
    '''Wrapper to help start the game'''
    config = 'OneVsOne-v0'
    record_pngs_dir = None #f'C:/tmp/Results/PNGS'
    record_json_dir = None #f'C:/tmp/Results/JSON'
    csv_dir = f'C:/tmp/Results/CSV'
    game_state_file = None
    render_mode = 'human'
    do_sleep = False
    render = False

    if not os.path.isdir(csv_dir):
        os.makedirs(csv_dir)
    game_details = [['p1','p2','result','winner','time','steps', 'add_info_p1', 'add_info_p2']]
    write_csv_pos = 0

    duel_num = 0
    total_duels = len(agent_pool1) * len(agent_pool2)
    game_num = 0
    total_games = total_duels * match_count * 2
    p1_num = 0
    for p1_a in agent_pool1:
        if AllVsAll:
            tmp_agent_pool2 = agent_pool2
        else:
            tmp_agent_pool2 = [agent_pool2[p1_num]]
        p1_num += 1
        for p2_a in tmp_agent_pool2:
            duel_num += 1
            print(f'Duel {duel_num}/{total_duels}')

            for d in range(2):
                if d == 0:
                    agents = [p1_a[1](**p1_a[2]), p2_a[1](**p2_a[2])]
                    agent_names = [p1_a[0], p2_a[0]]
                else:
                    agents = [p2_a[1](**p2_a[2]), p1_a[1](**p1_a[2])]
                    agent_names = [p2_a[0], p1_a[0]]

                env = make(config, agents, game_state_file, render_mode=render_mode)
                if seed is None:
                    # Pick a random seed between 0 and 2^31 - 1
                    seed = random.randint(0, np.iinfo(np.int32).max)
                np.random.seed(seed)
                random.seed(seed)
                env.seed(seed)

                for i in range(match_count):
                    game_num += 1

                    record_pngs_dir_ = None
                    record_json_dir_ = None
                    if record_pngs_dir:
                        record_pngs_dir_ = f'{record_pngs_dir}/{tournament_name}/{agent_names[0]}_vs_{agent_names[1]}_{i+1}'
                    if record_json_dir:
                        record_json_dir_ = f'{record_json_dir}/{tournament_name}/{agent_names[0]}_vs_{agent_names[1]}_{i+1}'

                    start = time.time()
                    info, steps = run(env, agent_names, config, render, do_sleep, record_pngs_dir_, record_json_dir_)
                    total_time = time.time() - start
                    winner = -1
                    if info['result'] == constants.Result.Win:
                        winner = int(info['winners'][0])

                    agent_info_1 = {}
                    agent_info_2 = {}
                    if isinstance(agents[0], AbstractMCTSSkeleton):
                        agents[0].get_agent_info(agent_info_1)
                    if isinstance(agents[1], AbstractMCTSSkeleton):
                        agents[1].get_agent_info(agent_info_2)

                    game_details.append([agent_names[0], agent_names[1], info['result'], winner, total_time, steps, agent_info_1, agent_info_2])

                    print(f"-- {game_num} / {total_games} Result: ", game_details[-1])

                atexit.register(env.close)

            f = open(f'{csv_dir}/{tournament_name}.csv', 'a')
            with f:
                writer = csv.writer(f, delimiter=';')
                while write_csv_pos < len(game_details):
                    writer.writerow(game_details[write_csv_pos])
                    write_csv_pos += 1

# %%
def run(env, agent_names, config, render, do_sleep, record_pngs_dir=None, record_json_dir=None):
    '''Runs a game'''
    if record_pngs_dir and not os.path.isdir(record_pngs_dir):
        os.makedirs(record_pngs_dir)
    if record_json_dir and not os.path.isdir(record_json_dir):
        os.makedirs(record_json_dir)

    obs = env.reset()
    done = False

    steps = 0
    while not done:
        if render:
            env.render(
                record_pngs_dir=record_pngs_dir,
                record_json_dir=record_json_dir,
                do_sleep=do_sleep)
        if render is False and record_json_dir:
            env.save_json(record_json_dir)
            time.sleep(1.0 / env._render_fps)
        actions = env.act(obs)
        steps += 1
        obs, reward, done, info = env.step(actions)

    if render:
        env.render(
            record_pngs_dir=record_pngs_dir,
            record_json_dir=record_json_dir,
            do_sleep=do_sleep)
        if do_sleep:
            time.sleep(5)
        env.render(close=True)

    if render is False and record_json_dir:
        env.save_json(record_json_dir)
        time.sleep(1.0 / env._render_fps)

    if record_json_dir:
        finished_at = datetime.now().isoformat()
        utility.join_json_state(record_json_dir, agent_names, finished_at,
                                config, info)

    return info, steps

# %%
def run_simple_vs_ucb():
    agent_pool1 = []
    agent_pool2 = []

    # create agents
    agent_simple = SimpleAgent
    agent_pool1.append(('SimpleAgent', agent_simple, {}))

    iters = [1] + [(i+1) * 20 for i in range(5)]
    for i in iters:
        agent_ucb = UcbLimitMCTSAgent
        kwargs = {'expandTreeRollout': False,
                  'maxIterations': i,
                  'maxTime': 0.0,
                  'discountFactor': 0.9999,
                  'depthLimit': None,
                  'C': 0.5}
        agent_pool2.append((
                           f'AgentUCBLimit_iter{kwargs["maxIterations"]}_df{kwargs["discountFactor"]}_dl{kwargs["depthLimit"]}_ex{kwargs["expandTreeRollout"]}_c{kwargs["C"]}',
                           agent_ucb, kwargs))

    # Tournament Settings
    tournament_name = 'Simple_Against_UCBLimit_' + datetime.now().strftime("%m-%d-%Y_%H-%M-%S")
    match_count = 50

    run_tournament(tournament_name, agent_pool1, agent_pool2, match_count)

# %%
def run_ucb_rnd_vs_limit():
    agent_pool1 = []
    agent_pool2 = []

    # create agents
    iters = [1] + [(i + 1) * 20 for i in range(5)]
    for i in iters:
        agent_ucb = UcbMCTSAgent
        kwargs = {'expandTreeRollout': False,
                  'maxIterations': i,
                  'maxTime': 0.0,
                  'discountFactor': 0.9999,
                  'depthLimit': None,
                  'C': 0.5}
        agent_pool1.append((
            f'AgentUCBLimit_iter{kwargs["maxIterations"]}_df{kwargs["discountFactor"]}_dl{kwargs["depthLimit"]}_ex{kwargs["expandTreeRollout"]}_c{kwargs["C"]}',
            agent_ucb, kwargs))

    for i in iters:
        agent_ucb = UcbLimitMCTSAgent
        kwargs = {'expandTreeRollout': False,
                  'maxIterations': i,
                  'maxTime': 0.0,
                  'discountFactor': 0.9999,
                  'depthLimit': None,
                  'C': 0.5}
        agent_pool2.append((
            f'AgentUCBLimit_iter{kwargs["maxIterations"]}_df{kwargs["discountFactor"]}_dl{kwargs["depthLimit"]}_ex{kwargs["expandTreeRollout"]}_c{kwargs["C"]}',
            agent_ucb, kwargs))

    # Tournament Settings
    tournament_name = 'UCB_Depth_Limit_Test' + datetime.now().strftime("%m-%d-%Y_%H-%M-%S")
    match_count = 10

    run_tournament(tournament_name, agent_pool1, agent_pool2, match_count, False)

# %%
run_simple_vs_ucb()
# Out:
# Duel 1/6
# -- 1 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter1_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 0.8527741432189941, 92, {}, {'avgTime': 0.007910065217391302, 'avgRolloutDepth': 23.413043478260885}]
# -- 2 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter1_df0.9999_dlNone_exFalse_c0.5', <Result.Tie: 2>, -1, 0.6556901931762695, 35, {}, {'avgTime': 0.01736385714285714, 'avgRolloutDepth': 60.19999999999999}]
# -- 3 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter1_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 0, 1.4069945812225342, 117, {}, {'avgTime': 0.01063133333333333, 'avgRolloutDepth': 32.64102564102562}]
# -- 4 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter1_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 1.0654377937316895, 120, {}, {'avgTime': 0.007539249999999998, 'avgRolloutDepth': 22.341666666666672}]
# -- 5 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter1_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 0.5918221473693848, 43, {}, {'avgTime': 0.0124816511627907, 'avgRolloutDepth': 42.53488372093023}]
# -- 6 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter1_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 0, 2.064075231552124, 95, {}, {'avgTime': 0.020342242105263166, 'avgRolloutDepth': 71.35789473684211}]
# -- 7 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter1_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 0, 0.7107133865356445, 52, {}, {'avgTime': 0.012412519230769229, 'avgRolloutDepth': 41.63461538461539}]
# -- 8 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter1_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 0, 2.031294822692871, 116, {}, {'avgTime': 0.016086456896551714, 'avgRolloutDepth': 54.25}]
# -- 9 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter1_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 0, 0.633636474609375, 42, {}, {'avgTime': 0.013745452380952379, 'avgRolloutDepth': 46.57142857142856}]
# -- 10 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter1_df0.9999_dlNone_exFalse_c0.5', <Result.Tie: 2>, -1, 0.49822425842285156, 30, {}, {'avgTime': 0.015322866666666666, 'avgRolloutDepth': 52.36666666666666}]
# -- 11 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter1_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 0, 0
/ 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter40_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 27.9816312789917, 66, {}, {'avgTime': 0.42277921212121194, 'avgRolloutDepth': 42.249999999999964}]
# -- 221 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter40_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 0, 23.444710969924927, 41, {}, {'avgTime': 0.5705997804878047, 'avgRolloutDepth': 58.482317073170684}]
# -- 222 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter40_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 26.7592613697052, 61, {}, {'avgTime': 0.4374638852459016, 'avgRolloutDepth': 44.24836065573763}]
# -- 223 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter40_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 12.639198780059814, 21, {}, {'avgTime': 0.6006882857142858, 'avgRolloutDepth': 60.07619047619043}]
# -- 224 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter40_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 11.911941051483154, 28, {}, {'avgTime': 0.4242253928571429, 'avgRolloutDepth': 43.5}]
# -- 225 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter40_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 101.47669720649719, 476, {}, {'avgTime': 0.21184725840336133, 'avgRolloutDepth': 19.41748949579821}]
# -- 226 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter40_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 14.311809062957764, 30, {}, {'avgTime': 0.4757536333333332, 'avgRolloutDepth': 46.96333333333332}]
# ...
# -- 413 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter80_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 90.55413436889648, 191, {}, {'avgTime': 0.47286017277486925, 'avgRolloutDepth': 21.820484293193672}]
# -- 414 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter80_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 84.56842613220215, 147, {}, {'avgTime': 0.5740179591836732, 'avgRolloutDepth': 27.92882653061205}]
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa040672c88>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa04114f710>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa040680780>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa0406804a8>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa040680630>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa040680400>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa040629780>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa040680978>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa040680a20>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa040680a58>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa040680ac8>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa040680b70>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa040680c18>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa040680cc0>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa040680d68>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!????? <pommerman.agents.abstract_mcts_agent.Node object at 0x7fa040680e10>
# no children!!!! 80 True 0
# No children available!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
/ 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter80_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 96.16448616981506, 106, {}, {'avgTime': 0.9058468113207548, 'avgRolloutDepth': 44.33797169811339}]
# -- 438 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter80_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 88.03792643547058, 125, {}, {'avgTime': 0.7029466320000002, 'avgRolloutDepth': 32.941800000000114}]
# -- 439 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter80_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 0, 78.94688487052917, 139, {}, {'avgTime': 0.5666942374100722, 'avgRolloutDepth': 26.44073741007194}]
# -- 440 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter80_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 28.516085624694824, 22, {}, {'avgTime': 1.2948560454545455, 'avgRolloutDepth': 65.15738636363632}]
# -- 441 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter80_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 0, 40.09855651855469, 51, {}, {'avgTime': 0.7849658235294118, 'avgRolloutDepth': 37.47843137254911}]
# -- 442 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter80_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 109.61348032951355, 215, {}, {'avgTime': 0.5085023255813954, 'avgRolloutDepth': 23.79284883720942}]
# -- 443 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter80_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 0, 30.622729301452637, 44, {}, {'avgTime': 0.6946418636363638, 'avgRolloutDepth': 34.08494318181826}]
# -- 444 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter80_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 25.021586656570435, 23, {}, {'avgTime': 1.0867528695652178, 'avgRolloutDepth': 56.988586956522006}]
# -- 445 / 600 Result:  ['SimpleAgent', 'AgentUCBLimit_iter80_df0.9999_dlNone_exFalse_c0.5', <Result.Win: 0>, 1, 34.77741503715515, 32, {}, {'avgTime': 1.0856625624999996, 'avgRolloutDepth': 53.758984374999756}]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-cfcca1ed7bae> in <module>()
# ----> 1 run_simple_vs_ucb()
#
# <ipython-input-26-ff6c2a0cec8d> in run_simple_vs_ucb()
#      24     match_count = 50
#      25
# ---> 26     run_tournament(tournament_name, agent_pool1, agent_pool2, match_count)
#
# <ipython-input-24-585532a56804> in run_tournament(tournament_name, agent_pool1, agent_pool2, match_count, AllVsAll, seed)
#      57
#      58                     start = time.time()
# ---> 59                     info, steps = run(env, agent_names, config, render, do_sleep, record_pngs_dir_, record_json_dir_)
#      60                     total_time = time.time() - start
#      61                     winner = -1
#
# <ipython-input-25-c362566b3ece> in run(env, agent_names, config, render, do_sleep, record_pngs_dir, record_json_dir)
#      19             env.save_json(record_json_dir)
#      20             time.sleep(1.0 / env._render_fps)
# ---> 21         actions = env.act(obs)
#      22         steps += 1
#      23         obs, reward, done, info = env.step(actions)
#
# /content/drive/My Drive/Bachelorarbeit/pommerman/envs/v0.py in act(self, obs)
#     134         agents = [agent for agent in self._agents \
#     135                   if agent.agent_id != self.training_agent]
# --> 136         return self.model.act(agents, obs, self.action_space)
#     137
#     138     def get_observations(self):
#
# /content/drive/My Drive/Bachelorarbeit/pommerman/forward_model.py in act(agents, obs, action_space, is_communicative)
#     120                 ret.append(act_with_communication(agent))
#     121             else:
# --> 122                 ret.append(act_ex_communication(agent))
#     123         return ret
#     124
#
# /content/drive/My Drive/Bachelorarbeit/pommerman/forward_model.py in act_ex_communication(agent)
#      99             '''Handles agent's move without communication'''
#     100             if agent.is_alive:
# --> 101                 return agent.act(obs[agent.agent_id], action_space=action_space)
#     102             else:
#     103                 return constants.Action.Stop.value
#
# /content/drive/My Drive/Bachelorarbeit/pommerman/agents/abstract_mcts_skeleton.py in act(self, obs, action_space)
#      35             iterations += 1
#      36             leaf = self.traverse(root)
# ---> 37             simulation_result, leaf = self.rollout(leaf)
#      38             self.backpropagate(leaf, simulation_result)
#      39
#
# /content/drive/My Drive/Bachelorarbeit/pommerman/agents/abstract_mcts_skeleton.py in rollout(self, node)
#      68             depth += 1
#      69             #save_copy_data = copy.deepcopy(data)
# ---> 70             node, data = self.rollout_policy(node, data)
#      71
#      72         #self.get_valid_actions(save_copy_data, 0, range(6))
#
# /content/drive/My Drive/Bachelorarbeit/pommerman/agents/abstract_mcts_agent.py in rollout_policy(self, node, data)
#     112
#     113         if self.expandTreeRollout: new_node = node.expand(actions[self.enemies[0].value - 10], data, self)
# --> 114         else: new_node = self.create_node(node.depth + 1, data, node.action_space, self.agent_id, self.enemies[0].value - 10, actions[self.enemies[0].value - 10], False)
#     115
#     116         return new_node, data
#
# /content/drive/My Drive/Bachelorarbeit/pommerman/agents/ucb_limit_mcts_agent.py in create_node(self, depth, game_data, action_space, agent_id, enemy_id, action, save_data)
#      23         node = UcbMCTSAgent.create_node(self, depth, game_data, action_space, agent_id, enemy_id, action, save_data)
#      24
# ---> 25         node.unseen_actions = self.get_valid_actions(game_data, agent_id, node.unseen_actions)
#      26         return node
#      27
#
# /content/drive/My Drive/Bachelorarbeit/pommerman/agents/ucb_limit_mcts_agent.py in get_valid_actions(self, game_data, agent_id, actions)
#      32             if agent.agent_id is agent_id:
#      33                 if agent.is_alive:
# ---> 34                     valid_actions = EnvSimulator.get_valid_actions(game_data.board, game_data.flames, game_data.bombs, agent, actions)
#      35                 else:
#      36                     valid_actions.append(constants.Action.Stop.value)
#
# /content/drive/My Drive/Bachelorarbeit/pommerman/agents/env_simulator.py in get_valid_actions(board, flames, bombs, agent, actions)
#     188                 if invalid_positions is None:
#     189                     invalid_positions = EnvSimulator.get_invalid_positions(board, flames, bombs)
# --> 190                 if EnvSimulator.is_valid_direction(board, row, col, action, invalid_values, invalid_positions):
#     191                     valid_actions.append(action)
#     192         return valid_actions
#
# /content/drive/My Drive/Bachelorarbeit/pommerman/agents/env_simulator.py in is_valid_direction(board, row, col, direction, invalid_values, invalid_positions)
#     267             return row - 1 >= 0 and board[row - 1][col] not in invalid_values and (
#     268             row - 1, col) not in invalid_positions
# --> 269         elif constants.Action(direction) == constants.Action.Down:
#     270             return row + 1 < len(board) and board[row + 1][col] not in invalid_values and (
#     271             row + 1, col) not in invalid_positions
#
# /usr/lib/python3.6/enum.py in __call__(cls, value, names, module, qualname, type, start)
#     291         """
#     292         if names is None:  # simple value lookup
# --> 293             return cls.__new__(cls, value)
#     294         # otherwise, functional API: we're creating a new Enum type
#     295         return cls._create_(value, names, module=module, qualname=qualname, type=type, start=start)
#
# /usr/lib/python3.6/enum.py in __new__(cls, value)
#     525         # see if it's in the reverse mapping (for hashable values)
#     526         try:
# --> 527             if value in cls._value2member_map_:
#     528                 return cls._value2member_map_[value]
#     529         except TypeError:
#
# KeyboardInterrupt:
